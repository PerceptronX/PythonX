# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -  __Python__ is a high-level, interpreted, interactive and object-oriented scripting language. Python is designed to be highly readable. It uses English keywords frequently where as other languages use punctuation, and it has fewer syntactical constructions than other languages.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ## Python Variables

# %%
var=20
print(var)
# Out:
# 20

# %%
id(var)
# Out:
# 1859427304272

# %%
id(20)
# Out:
# 1859427304272

# %%
print(var)
# Out:
# 20

# %%
var2='bbb'
id(var2)
# Out:
# 1859464080176

# %%
print(var2)
# Out:
# bbb

# %% [markdown]
# ## creating python variable

# %%
var1=20
var3="orissa"
var4=10.2
print(var1,var3,var4)
# Out:
# 20 orissa 10.2

# %%
print(f"first variable={var1} second variable={var3},third variable={var4}")
# Out:
# first variable=20 second variable=orissa,third variable=10.2

# %% [markdown]
# ## Deleting python variables

# %%
del var1

# %%
var1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 var1
#
# NameError: name 'var1' is not defined

# %% [markdown]
# ## Getting Type of a Variable

# %%
vr1=25
vr2="hello"
print(type(vr1))
# Out:
# <class 'int'>

# %%
print(type(vr2))
# Out:
# <class 'str'>

# %% [markdown]
# ## Casting Python Variables

# %%
x=10
y=float(x)
print(y)
# Out:
# 10.0

# %%
z=str(x)
print(z)
# Out:
# 10

# %% [markdown]
# # case sensetive

# %%
var="zzz"
var2="ZZZ"
if var==var2:
    print("not case sensetive")
else:
    print("case sensetive")
# Out:
# case sensetive

# %% [markdown]
# ## invalid python variable name

# %%
1counter = 100
$_count  = 100
zara-salary = 100000
# Out:
#   Cell In[25], line 1
#     1counter = 100
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ## Python Data Types

# %% [markdown]
# -  Python Data Types are used to define the type of a variable. It defines what type of data we are going to store in a variable. The data stored in memory can be of many types. For example, a person's age is stored as a numeric value and his or her address is stored as alphanumeric characters.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Python Numeric Data Type
# -  Python supports four different numerical types and each of them have built-in classes in Python library, called int, bool, float and complex respectively

# %%
var1 = 1       # int data type
var2 = True    # bool data type
var3 = 10.023  # float data type
var4 = 10+3j   # complex data type

# %% [markdown]
# ## Python Sequence Data Type

# %% [markdown]
# -  Sequence is a collection data type. It is an ordered collection of items. Items in the sequence have a positional index starting with 0. There are following three sequence data types defined in Python.

# %% [markdown]
# ## String

# %%
str = 'Hello World!'

print (str)          # Prints complete string
print (str[0])       # Prints first character of the string
print (str[2:5])     # Prints characters starting from 3rd to 5th
print (str[2:])      # Prints string starting from 3rd character
print (str * 2)      # Prints string two times
print (str + "TEST")
# Out:
# Hello World!
# H
# llo
# llo World!
# Hello World!Hello World!
# Hello World!TEST

# %% [markdown]
# ## List

# %%
list = [ 'abcd', 786 , 2.23, 'john', 70.2 ]
tinylist = [123, 'john']

print (list)            # Prints complete list
print (list[0])         # Prints first element of the list
print (list[1:3])       # Prints elements starting from 2nd till 3rd 
print (list[2:])        # Prints elements starting from 3rd element
print (tinylist * 2)    # Prints list two times
print (list + tinylist) # Prints concatenated lists
# Out:
# ['abcd', 786, 2.23, 'john', 70.2]
# abcd
# [786, 2.23]
# [2.23, 'john', 70.2]
# [123, 'john', 123, 'john']
# ['abcd', 786, 2.23, 'john', 70.2, 123, 'john']

# %% [markdown]
# ## Tuple Data Type

# %%
t=(2023, "Python", 3.11, 5+6j, 1.23E-4)
print(t)
# Out:
# (2023, 'Python', 3.11, (5+6j), 0.000123)

# %% [markdown]
# ## range

# %%
## range(start, stop, step)
range(0, 10, 2)
# Out:
# range(0, 10, 2)

# %% [markdown]
# ## Python Dictionary Data Type

# %%
d={1:'one', 2:'two', 3:'three'}
d
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
d[1]
# Out:
# 'one'

# %%
dict = {}
dict['one'] = "This is one"
dict[2]     = "This is two"

print(dict)
# Out:
# {'one': 'This is one', 2: 'This is two'}

# %% [markdown]
# # Python Set Data Type

# %%
s={2023, "Python", 3.11, 5+6j, 1.23E-4}

# %%
s
# Out:
# {(5+6j), 0.000123, 2023, 3.11, 'Python'}

# %% [markdown]
# ## Python Boolean Data Types

# %%
a = True
# display the value of a
print(a)
# Out:
# True

# %% [markdown]
# ## Dictionary

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# syntax
d={1:"boys",2:"girls"}

# %%
d
# Out:
# {1: 'boys', 2: 'girls'}

# %%
d[2]
# Out:
# 'girls'

# %%
d.keys()
# Out:
# dict_keys([1, 2])

# %%
d.values()
# Out:
# dict_values(['boys', 'girls'])

# %%
d.get(1)
# Out:
# 'boys'

# %%
d.items()
# Out:
# dict_items([(1, 'boys'), (2, 'girls')])

# %%
d[3]="oldman"

# %%
d
# Out:
# {1: 'boys', 2: 'girls', 3: 'oldman'}

# %%
d.update({1:"uncle"})

# %%
d
# Out:
# {1: 'uncle', 2: 'girls', 3: 'oldman'}

# %%
d.pop(3)
# Out:
# 'oldman'

# %%
d
# Out:
# {1: 'uncle', 2: 'girls'}

# %%
del(d[2])

# %%
d
# Out:
# {1: 'uncle'}

# %%
d.clear()

# %%
d
# Out:
# {}
